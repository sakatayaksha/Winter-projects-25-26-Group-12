# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## A bit of info before you start.
#
#
# > ***First and foremost, dont use AI to code. Use it to understand and then write code yourself. Use AI to verify if the code you wrote it correct, that will help you learn far far more.***
#
# > ***Implement Stuff from sratch. Use cv2 functions only when numpy implementation can be extremely tedious.***
#
#
#
# You will need to use your own image for this assignment, which you need to import into here.
# If you cant fetch your image from any APIs that dont need credentials, then :
# To preserve an image in Google Colab without a continuous runtime or using Google Drive, you can use base64 string encoding of images ( its really simple )
#
# First, begin by normally uploading the image into the contents folders as you normally do in colab or fetch it using Drive or any API.
#
# To get the base64 string :
# ```
# import base64
# with open("your_image.jpg", "rb") as img_file:
#     print(base64.b64encode(img_file.read()).decode())
# ```
#
# Note that the base64 string is a very long string, click on the three dot icon to the left of the current code cell and click on <code> Copy Cell Output </code> to easily copy it to your clipboard.
#
# Then, to embed the string into your Jupyter Notebook :
# ```
# from PIL import Image
# import io
# import base64
# import matplotlib.pyplot as plt
# import numpy as np
#
# # PASTE BASE64 STRING HERE
# base64_image = "iVBORw0K..."  # long base64 string
#
# img_data = base64.b64decode(base64_image)
# img = Image.open(io.BytesIO(img_data))
#
# plt.imshow(img)
# plt.axis("off")
# ```
# The string is really long so, use a multiline string in python ( syntax : """ """ )
#
# Otherwise, you can also choose to use any API ( try researching on https://picsum.photos/ )

# %% [markdown]
# ## SECTION 1 : Preparations

# %%
# @title
from PIL import Image
import io
import base64
import matplotlib.pyplot as plt
import numpy as np

img_str = """
...
"""

img_data = base64.b64decode(img_str)
img = Image.open(io.BytesIO(img_data))
img_part5 = np.array(img)

plt.imshow(img_part5)
plt.axis("off")
plt.title("Our Image")
plt.show()

# %% [markdown]
# ## SECTION 2 : Questions
#
# Embed your own image, the above shown is specifically for last part.

# %% [markdown]
# ### Part A
#
# #### Task 1 - Convolution
# Write a function <code>convolve(img, kernel)</code>
# Hint : Lookup <code>np.pad</code> function for padding and research how it works. It takes different modes, one that we want to use is <code>reflect</code>
# Also, learn what exactly <code>*</code> does ( particularly if it can convolve matrices of different sizes and if at all you use it, then where you can and where you cannot ). Use it later on for your ease.
#
# #### Task 2 — Average Blur
#
# Implement a function <code>average_blur_gray(img, ksize)</code> using:
# * A box kernel of size ksize × ksize
# * Only NumPy (no cv2 filtering functions)
#
# Repeat for RGB:
#
# * Apply the kernel on each channel separately.
#
# #### Task 3 - Gaussian Blur
#
# 1. Implement a Gaussian kernel generator:
# The function signature should be <code>gaussian_kernel(ksize, sigma)</code>
# It should return a numpy matrix that is the normalsied gaussian kernel with dimensions ksize x ksize and the 2D gaussian distribution calculation done with standard deviation as sigma. I had talked about it in the lecture, for any queries, research first cuz its not hard to put in values and compute.
#
# 2. Convolve it with:
# * Gray image
# * Each RGB channel
#
# And, then display all results along with the original image.

# %%
# Your PART A codes follow here. You can create more cells under this. Write clean and commented code.


import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import io
import base64

# PASTE BASE64 STRING HERE
base64_image = """
...
"""

img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data)).convert("RGB")
img_np = np.array(img)

plt.imshow(img_np)
plt.axis("off")
plt.title("Original Image")
plt.show()


# RGB TO GRAYSCALE


def rgb_to_gray(img):
    return (0.299 * img[..., 0] +
            0.587 * img[..., 1] +
            0.114 * img[..., 2]).astype(np.float32)

gray = rgb_to_gray(img_np)



# TASK 1 : CONVOLUTION


def convolve(img, kernel):
    kh, kw = kernel.shape
    pad_h = kh // 2
    pad_w = kw // 2

    padded_img = np.pad(
        img,
        ((pad_h, pad_h), (pad_w, pad_w)),
        mode="reflect"
    )

    h, w = img.shape
    output = np.zeros((h, w), dtype=np.float32)

    for i in range(h):
        for j in range(w):
            region = padded_img[i:i+kh, j:j+kw]
            output[i, j] = np.sum(region * kernel)

    return output



# TASK 2 : AVERAGE BLUR


def average_blur_gray(img, ksize):
    kernel = np.ones((ksize, ksize), dtype=np.float32)
    kernel /= (ksize * ksize)
    return convolve(img, kernel)

def average_blur_rgb(img, ksize):
    output = np.zeros_like(img, dtype=np.float32)
    for c in range(3):
        output[..., c] = average_blur_gray(
            img[..., c].astype(np.float32), ksize
        )
    return output



# TASK 3 : GAUSSIAN BLUR


def gaussian_kernel(ksize, sigma):
    ax = np.arange(-(ksize // 2), ksize // 2 + 1)
    xx, yy = np.meshgrid(ax, ax)

    kernel = np.exp(-(xx**2 + yy**2) / (2 * sigma**2))
    kernel /= np.sum(kernel)

    return kernel.astype(np.float32)

def gaussian_blur_gray(img, ksize, sigma):
    kernel = gaussian_kernel(ksize, sigma)
    return convolve(img, kernel)

def gaussian_blur_rgb(img, ksize, sigma):
    kernel = gaussian_kernel(ksize, sigma)
    output = np.zeros_like(img, dtype=np.float32)

    for c in range(3):
        output[..., c] = convolve(
            img[..., c].astype(np.float32), kernel
        )

    return output


avg_gray = average_blur_gray(gray, ksize=5)
avg_rgb = average_blur_rgb(img_np, ksize=5)

gauss_gray = gaussian_blur_gray(gray, ksize=5, sigma=1.0)
gauss_rgb = gaussian_blur_rgb(img_np, ksize=5, sigma=1.0)

# VISUALIZATION

plt.figure(figsize=(16, 10))

plt.subplot(2, 3, 1)
plt.imshow(img_np)
plt.title("Original RGB")
plt.axis("off")

plt.subplot(2, 3, 2)
plt.imshow(gray, cmap="gray")
plt.title("Grayscale")
plt.axis("off")

plt.subplot(2, 3, 3)
plt.imshow(avg_gray, cmap="gray")
plt.title("Average Blur (Gray)")
plt.axis("off")

plt.subplot(2, 3, 4)
plt.imshow(avg_rgb.astype(np.uint8))
plt.title("Average Blur (RGB)")
plt.axis("off")

plt.subplot(2, 3, 5)
plt.imshow(gauss_gray, cmap="gray")
plt.title("Gaussian Blur (Gray)")
plt.axis("off")

plt.subplot(2, 3, 6)
plt.imshow(gauss_rgb.astype(np.uint8))
plt.title("Gaussian Blur (RGB)")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Part B
#
# #### Task - Sobel Edge Detection (NumPy Only)
# Implement Sobel X and Sobel Y filters manually using convolution. Apply on the grayscale image.
#
# Compute:
# 1. Gx
# 2. Gy
# 3. Gradient magnitude
#
# Normalize to 0–255 and save the edge map. Threshold if you wish to, if you do then make the thresholding part clear using code comments.

# %%
# Your PART B codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import io
import base64

base64_image = """
...
"""

img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data)).convert("RGB")
img_np = np.array(img)

plt.imshow(img_np)
plt.title("Original Image")
plt.axis("off")
plt.show()


def rgb_to_gray(img):
    return (0.299 * img[..., 0] +
            0.587 * img[..., 1] +
            0.114 * img[..., 2]).astype(np.float32)

gray = rgb_to_gray(img_np)


def convolve(img, kernel):
    kh, kw = kernel.shape
    pad_h = kh // 2
    pad_w = kw // 2

    padded = np.pad(
        img,
        ((pad_h, pad_h), (pad_w, pad_w)),
        mode="reflect"
    )

    h, w = img.shape
    output = np.zeros((h, w), dtype=np.float32)

    for i in range(h):
        for j in range(w):
            region = padded[i:i+kh, j:j+kw]
            output[i, j] = np.sum(region * kernel)

    return output


sobel_x = np.array([
    [-1,  0,  1],
    [-2,  0,  2],
    [-1,  0,  1]
], dtype=np.float32)

sobel_y = np.array([
    [-1, -2, -1],
    [ 0,  0,  0],
    [ 1,  2,  1]
], dtype=np.float32)

# APPLY SOBEL FILTERS


Gx = convolve(gray, sobel_x)
Gy = convolve(gray, sobel_y)

# GRADIENT MAGNITUDE


gradient_magnitude = np.sqrt(Gx**2 + Gy**2)


gradient_magnitude_norm = (
    255 * gradient_magnitude / gradient_magnitude.max()
).astype(np.uint8)


# Without thresholding
edge_map = gradient_magnitude_norm

# VISUALIZATION


plt.figure(figsize=(14, 8))

plt.subplot(2, 3, 1)
plt.imshow(gray, cmap="gray")
plt.title("Grayscale Image")
plt.axis("off")

plt.subplot(2, 3, 2)
plt.imshow(Gx, cmap="gray")
plt.title("Sobel Gx")
plt.axis("off")

plt.subplot(2, 3, 3)
plt.imshow(Gy, cmap="gray")
plt.title("Sobel Gy")
plt.axis("off")

plt.subplot(2, 3, 4)
plt.imshow(gradient_magnitude, cmap="gray")
plt.title("Gradient Magnitude (Raw)")
plt.axis("off")

plt.subplot(2, 3, 5)
plt.imshow(gradient_magnitude_norm, cmap="gray")
plt.title("Gradient Magnitude (Normalized)")
plt.axis("off")

plt.subplot(2, 3, 6)
plt.imshow(edge_map, cmap="gray")
plt.title("Final Edge Map")
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Part C
#
# #### Task 1 — Laplacian Sharpening ( Only Numpy and Grayscale )
# 1. Use any 3×3 Laplacian kernel (4-connected or 8-connected).
#
# 2. Compute:
# * <code>lap = convolve(img, laplacian_kernel)</code>
# * <code>sharp = img - lap * alpha</code> where alpha ∈ [0.2, 1].
#
# 3. Now, put alpha = 1, if you had chosen a different value earlier. Get a new output. Then use the code in the lecture to do the same using cv2. Now, use python to verify if both numpy with alpha = 1 and cv2 give the exact same output ( Compare the matrices )
#
# #### Task 2 - Unsharp Masking ( Only Numpy and Grayscale )
# 1. Apply Gaussian blur (from Part 1).
# 2. Subtract blurred image from original: <code> mask = img - blurred </code>
# 3. Add scaled mask back: <code>sharp = img + alpha * mask</code> , where you can choose any value of alpha.
# 4. See how negative values of alpha will give you a blurred image.

# %%
# Your PART C codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import io
import base64
import cv2

base64_image = """
...
"""

img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data)).convert("L")
img_np = np.array(img).astype(np.float32)

plt.imshow(img_np, cmap="gray")
plt.title("Original Grayscale Image")
plt.axis("off")
plt.show()

# CONVOLUTION FUNCTION (NUMPY ONLY)

def convolve(img, kernel):
    kh, kw = kernel.shape
    pad_h = kh // 2
    pad_w = kw // 2

    padded = np.pad(img, ((pad_h, pad_h), (pad_w, pad_w)), mode="reflect")

    h, w = img.shape
    output = np.zeros((h, w), dtype=np.float32)

    for i in range(h):
        for j in range(w):
            region = padded[i:i+kh, j:j+kw]
            output[i, j] = np.sum(region * kernel)

    return output

# TASK 1 : LAPLACIAN SHARPENING

laplacian_kernel = np.array([
    [0, -1, 0],
    [-1, 4, -1],
    [0, -1, 0]
], dtype=np.float32)

lap = convolve(img_np, laplacian_kernel)

alpha = 0.5
sharp_numpy = img_np - alpha * lap

sharp_numpy_alpha1 = img_np - lap

lap_cv2 = cv2.Laplacian(img_np, cv2.CV_32F, ksize=3)
sharp_cv2 = img_np - lap_cv2

difference = np.abs(sharp_numpy_alpha1 - sharp_cv2)
max_difference = np.max(difference)
print("Max difference:", max_difference)

# VISUALIZATION : LAPLACIAN SHARPENING

plt.figure(figsize=(14, 6))

plt.subplot(1, 3, 1)
plt.imshow(lap, cmap="gray")
plt.title("Laplacian")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(sharp_numpy_alpha1, cmap="gray")
plt.title("Sharpened (NumPy)")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(sharp_cv2, cmap="gray")
plt.title("Sharpened (cv2)")
plt.axis("off")

plt.tight_layout()
plt.show()

# TASK 2 : UNSHARP MASKING (NUMPY ONLY)


def gaussian_kernel(ksize, sigma):
    ax = np.arange(-(ksize // 2), ksize // 2 + 1)
    xx, yy = np.meshgrid(ax, ax)
    kernel = np.exp(-(xx**2 + yy**2) / (2 * sigma**2))
    kernel /= np.sum(kernel)
    return kernel.astype(np.float32)

def gaussian_blur(img, ksize, sigma):
    kernel = gaussian_kernel(ksize, sigma)
    return convolve(img, kernel)

blurred = gaussian_blur(img_np, 5, 1.0)
mask = img_np - blurred

alpha_usm = 0.7
sharp_usm = img_np + alpha_usm * mask

alpha_negative = -0.5
blurred_via_negative_alpha = img_np + alpha_negative * mask

# VISUALIZATION

plt.figure(figsize=(16, 8))

plt.subplot(2, 3, 1)
plt.imshow(img_np, cmap="gray")
plt.title("Original")
plt.axis("off")

plt.subplot(2, 3, 2)
plt.imshow(blurred, cmap="gray")
plt.title("Gaussian Blurred")
plt.axis("off")

plt.subplot(2, 3, 3)
plt.imshow(mask, cmap="gray")
plt.title("Mask")
plt.axis("off")

plt.subplot(2, 3, 4)
plt.imshow(sharp_usm, cmap="gray")
plt.title("Unsharp Masking")
plt.axis("off")

plt.subplot(2, 3, 5)
plt.imshow(blurred_via_negative_alpha, cmap="gray")
plt.title("Negative Alpha Effect")
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# Max difference: 1542.0

# %% [markdown]
# ### Part D
#
# #### Task - Frequency Analysis (LPF & HPF Verification)
# Compute the magnitude spectrum of the original image, gaussian blurred image and the unsharp masking image. Now, play with the alpha value in sharpening and gaussian kernel and notice how the magntude spectrum changes.
# Then, in code comments, explain your observations of dark and bright areas in the magnitude spectrum. In nutshell, verify how convolution is actually filtering frequencies depending on the kernel.

# %%
# Your PART D codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import io
import base64

base64_image = """
...
"""

img_data = base64.b64decode(base64_image)
img = Image.open(io.BytesIO(img_data)).convert("L")
img = np.array(img).astype(np.float32)

def convolve(img, kernel):
    kh, kw = kernel.shape
    pad_h = kh // 2
    pad_w = kw // 2
    padded = np.pad(img, ((pad_h, pad_h), (pad_w, pad_w)), mode="reflect")
    h, w = img.shape
    out = np.zeros((h, w), dtype=np.float32)
    for i in range(h):
        for j in range(w):
            out[i, j] = np.sum(padded[i:i+kh, j:j+kw] * kernel)
    return out

def gaussian_kernel(ksize, sigma):
    ax = np.arange(-(ksize//2), ksize//2 + 1)
    xx, yy = np.meshgrid(ax, ax)
    k = np.exp(-(xx**2 + yy**2) / (2 * sigma**2))
    return k / np.sum(k)

def gaussian_blur(img, ksize, sigma):
    return convolve(img, gaussian_kernel(ksize, sigma))

blurred = gaussian_blur(img, 5, 1.0)

mask = img - blurred
alpha = 1.0
sharp = img + alpha * mask

def magnitude_spectrum(img):
    f = np.fft.fft2(img)
    fshift = np.fft.fftshift(f)
    mag = np.log(1 + np.abs(fshift))
    return mag

spec_original = magnitude_spectrum(img)
spec_blurred = magnitude_spectrum(blurred)
spec_sharp = magnitude_spectrum(sharp)

plt.figure(figsize=(15, 9))

plt.subplot(2, 3, 1)
plt.imshow(img, cmap="gray")
plt.title("Original")
plt.axis("off")

plt.subplot(2, 3, 2)
plt.imshow(blurred, cmap="gray")
plt.title("Gaussian Blurred")
plt.axis("off")

plt.subplot(2, 3, 3)
plt.imshow(sharp, cmap="gray")
plt.title("Unsharp Masking")
plt.axis("off")

plt.subplot(2, 3, 4)
plt.imshow(spec_original, cmap="gray")
plt.title("Spectrum: Original")
plt.axis("off")

plt.subplot(2, 3, 5)
plt.imshow(spec_blurred, cmap="gray")
plt.title("Spectrum: Gaussian Blur")
plt.axis("off")

plt.subplot(2, 3, 6)
plt.imshow(spec_sharp, cmap="gray")
plt.title("Spectrum: Unsharp Masking")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
"""
The magnitude spectrum of the original image shows a bright region concentrated
at the center, indicating dominance of low-frequency components corresponding
to smooth intensity variations, while the dimmer outer regions represent
high-frequency components such as edges and fine textures.

After applying Gaussian blur, the magnitude spectrum becomes more concentrated
towards the center. The outer regions appear significantly darker, confirming
that high-frequency components have been attenuated. This demonstrates that
Gaussian convolution suppresses edges and fine details and therefore acts as
a low-pass filter in the frequency domain.

For the unsharp masking result, the magnitude spectrum exhibits increased
brightness in the outer regions compared to the original image. This indicates
amplification of high-frequency components corresponding to edges and sharp
transitions. The enhancement becomes more pronounced as the sharpening factor
alpha is increased.

By varying the Gaussian kernel parameters and the sharpening factor, it is
observed that convolution in the spatial domain directly controls the frequency
response of the image. Smoothing kernels reduce high-frequency content, while
sharpening operations enhance high-frequency components, verifying the
low-pass and high-pass filtering behavior of these operations.
"""
# Out:
# '\nThe magnitude spectrum of the original image shows a bright region concentrated\nat the center, indicating dominance of low-frequency components corresponding\nto smooth intensity variations, while the dimmer outer regions represent\nhigh-frequency components such as edges and fine textures.\n\nAfter applying Gaussian blur, the magnitude spectrum becomes more concentrated\ntowards the center. The outer regions appear significantly darker, confirming\nthat high-frequency components have been attenuated. This demonstrates that\nGaussian convolution suppresses edges and fine details and therefore acts as\na low-pass filter in the frequency domain.\n\nFor the unsharp masking result, the magnitude spectrum exhibits increased\nbrightness in the outer regions compared to the original image. This indicates\namplification of high-frequency components corresponding to edges and sharp\ntransitions. The enhancement becomes more pronounced as the sharpening factor\nalpha is increased.\n\nBy varying the Gaussian kernel parameters and the sharpening factor, it is\nobserved that convolution in the spatial domain directly controls the frequency\nresponse of the image. Smoothing kernels reduce high-frequency content, while\nsharpening operations enhance high-frequency components, verifying the\nlow-pass and high-pass filtering behavior of these operations.\n'

# %% [markdown]
# ### Part E
#
# #### Task - Custom Colour Kernel (Detect Yellow Leaf Edges)
#
# **Instructions :**
# * At the start of the assignment .ipynb file, you will find a code cell in section 1, run it to see an image with a yellow leaf amongst green leaves.
# * Design a 3×3 or 5×5 custom kernel applied separately to each channel that highlights the edges where any other colour transitions into a yellowish hue.
#
# **Hints :**
#
# * Yellow = (R high, G high, B low)
#
# * Dark green = (G high, R low, B low)
#
# **Steps:**
#
# 1. Analyze the RGB values of green & yellow regions.
#
# 2. Create a custom kernel that responds strongly to change from green to yellow in:
# * Red matrices of RGB
# * Green matrices of RGB
# * Optionally R - G difference
# * Think about the gradient in Red - Green. Is there a huge change the value of R-G when colour changes from Green to Yellow ? If yes, try to exploit it.
#
# 3. Combine the response maps.
#
# 4. Get a clean outline around the leaf.

# %%
plt.imshow(img_part5)
plt.axis("off")
plt.title("Our Image")
plt.show()

# %%
# Your PART E codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

img = img_part5.astype(np.float32)

R = img[:, :, 0]
G = img[:, :, 1]
B = img[:, :, 2]

RG_diff = R - G
RG_diff[RG_diff < 0] = 0

yellow_strength = R + G - 2 * B
yellow_strength[yellow_strength < 0] = 0

kernel = np.array([
    [-1,  0,  1],
    [-2,  0,  2],
    [-1,  0,  1]
], dtype=np.float32)

edge_RG = cv2.filter2D(RG_diff, -1, kernel)
edge_Y  = cv2.filter2D(yellow_strength, -1, kernel)

combined_edges = edge_RG + edge_Y
combined_edges = np.abs(combined_edges)

combined_edges = cv2.normalize(
    combined_edges, None, 0, 255, cv2.NORM_MINMAX
).astype(np.uint8)

_, edge_map = cv2.threshold(
    combined_edges, 60, 255, cv2.THRESH_BINARY
)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(combined_edges, cmap="gray")
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(edge_map, cmap="gray")
plt.axis("off")

plt.show()

# %% [markdown]
# ### Bonus - Part F
#
# #### Task - Color Manipulation Using Lecture 2 Concepts
#
# **NOTE :** only for this, you can use cv2 functions, no need of doing everything in Numpy. Although there are still more brownie parts for Numpy hardwork.
#
# 1. Convert the RGB image to HSV. Use your rgb_to_hsv() from Lecture 2 Assignment - free Numopy points ;)) .
# 2. Identify pixels belonging to the yellow leaf using an HSV mask. (maybe take help from Part E or design a new hue mask)
# 3. Now use your full brain and chnage the colour of the leaf to red.
#
# Convert back to RGB.
#
# Display the final result.
#
# For reference, heres the image I expect as a result. And its not actually tough, easy 5 lines code.
# ![image.png](data:image/png;base64,...)
#
# Also, we can change to a less brighter colour
# ![image.png](data:image/png;base64,...)

# %%
# Your BONUS PART codes follow here. You can create more cells under this. Write clean and commented code.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = img_part5.copy()

hsv = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)

lower_yellow = np.array([15, 80, 80])
upper_yellow = np.array([35, 255, 255])

mask = cv2.inRange(hsv, lower_yellow, upper_yellow)

hsv_modified = hsv.copy()
hsv_modified[mask > 0, 0] = 0
hsv_modified[mask > 0, 1] = 200
hsv_modified[mask > 0, 2] = 180

result = cv2.cvtColor(hsv_modified, cv2.COLOR_HSV2RGB)

plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.imshow(img)
plt.axis("off")

plt.subplot(1, 2, 2)
plt.imshow(result)
plt.axis("off")

plt.show()
